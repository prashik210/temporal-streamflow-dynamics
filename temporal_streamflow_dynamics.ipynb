# %% [markdown]
# <a href="https://colab.research.google.com/github/prashik210/temporal-streamflow-dynamics/blob/main/temporal_streamflow_dynamics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn
import io
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-51a132fe-450e-49bf-9511-f0b865e19b41" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-51a132fe-450e-49bf-9511-f0b865e19b41">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Data1A.xlsx to Data1A.xlsx

# %%
df = pd.read_excel(io.BytesIO(uploaded.get('Data1A.xlsx')))

# %%
df
# Out:
#     Unnamed: 0    410730    410731  ...    G8190001    G8200045   G9030124
# 0   1981-01-01  4.852346  0.765016  ...  112.870686  128.589310   2.639920
# 1   1981-02-01  4.406532  0.702167  ...  368.428300  218.067600  35.251447
# 2   1981-03-01  2.215972  0.249210  ...  207.805040   82.104010   0.124965
# 3   1981-04-01  3.195213  0.598882  ...   10.906100    8.079920   0.000000
# 4   1981-05-01  6.016751  2.034761  ...    1.546898    2.921380   0.000000
# ..         ...       ...       ...  ...         ...         ...        ...
# 307 2006-08-01  8.999240  1.326764  ...    0.902243    3.854680   0.000086
# 308 2006-09-01  9.769320  1.316217  ...    2.226235    3.122670   0.000083
# 309 2006-10-01  4.374357  0.433617  ...    1.893038    3.113607   0.000086
# 310 2006-11-01  3.019922  0.286069  ...    1.724103    3.041110   0.000083
# 311 2006-12-01  1.138508  0.002766  ...    1.916348   12.330945   0.000086
#
# [312 rows x 219 columns]
